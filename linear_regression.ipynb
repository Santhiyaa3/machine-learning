# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
X = [[1], [2], [2.5], [3], [4], [4.5], [5], [6], [6.5], [7], [8], [9]]
Y = [50, 55, 60, 62, 68, 72, 75, 80, 82, 85, 90, 95]
print(X)
print(Y)
# Out:
# [[1], [2], [2.5], [3], [4], [4.5], [5], [6], [6.5], [7], [8], [9]]
# [50, 55, 60, 62, 68, 72, 75, 80, 82, 85, 90, 95]

# %%
plt.scatter(X, Y, color='purple')
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.title("Hours Studied vs Exam Score")
plt.show()

# %%
clf = LinearRegression()
clf.fit(X, Y)
print("R-squared Score:", clf.score(X, Y))
# Out:
# R-squared Score: 0.99559529922492

# %%
predicted_score = clf.predict([[5.5]])
print("Predicted Exam Score for 5.5 hours of study:", predicted_score[0])
# Out:
# Predicted Exam Score for 5.5 hours of study: 76.38164691583106

# %%
plt.scatter(X, Y, color='green')
plt.plot(X, clf.predict(X), color='blue')
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.title("Linear Regression - Study Hours vs Exam Score")
plt.show()
